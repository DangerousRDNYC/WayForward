# %%
import chart_studio
import chart_studio.plotly as py
chart_studio.tools.set_credentials_file(username='jarstone', api_key='ao4A1hWanJGvvocoTXlx')
import plotly.figure_factory as ff

import pandas as pd
mpg = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/mpg_2017.txt',delimiter = "\t")

fig = ff.create_facet_grid(
    mpg,
    x='displ',
    y='cty',
    facet_col='cyl',
    
)

py.iplot(fig, filename='facet by col')

# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

salary_data = pd.read_csv('Occupation_Salary.csv') 
workstyles = pd.read_csv('Work Styles.csv')
workstyles['Data Value'] = workstyles.apply(lambda x: x['Data Value']/5, axis = 1 )

workstylespivot = pd.pivot_table(workstyles, values='Data Value', index=['O*NET-SOC Code'],
                    columns=['Element Name'], aggfunc=np.sum)

jobzones = pd.read_csv('Job Zones.csv') 

workvalues = pd.read_csv('Work Values.csv')
workvalues['Score'] = workvalues.apply(lambda x: x['Score']/7, axis = 1 )

workvaluespivot = pd.pivot_table(workvalues, values='Score', index=['SOC Code'],
                    columns=['Element Name'], aggfunc=np.sum)

master_table = salary_data[['OCC_CODE', 'Adj Code', 'OCC_TITLE','A_MEAN']]
master_table['Sector'] = master_table['Adj Code'].str[:2]

master_table = master_table.merge(jobzones, left_on='OCC_CODE', right_on='O*NET-SOC Code')
master_table = master_table.merge(workvaluespivot, left_on='OCC_CODE', right_on='SOC Code')
master_table = master_table.merge(workstylespivot, left_on='OCC_CODE', right_on='O*NET-SOC Code')




print (master_table)
# Out:
#      OCC_CODE Adj Code_x                                  OCC_TITLE   A_MEAN  \
# 0      111011    13QQ001                           Chief Executives  200,140
# 1      111021    13QQ002            General and Operations Managers  123,880
# 2      112011    27QQ001        Advertising and Promotions Managers  133,090
# 3      112021    27QQ002                         Marketing Managers  147,240
# 4      112022    13QQ003                             Sales Managers  140,320
# ..        ...        ...                                        ...      ...
# 659    537072     537072    Pump Operators, Except Wellhead Pumpers   47,510
# 660    537073     537073                           Wellhead Pumpers   53,870
# 661    537081     537081  Refuse and Recyclable Material Collectors   40,560
# 662    537111     537111                 Mine Shuttle Car Operators   56,150
# 663    537121     537121          Tank Car, Truck, and Ship Loaders   42,330
#
#     Sector  O*NET-SOC Code  Adj Code_y  Code  \
# 0       13        111011.0      111011    11
# 1       13        111021.0      111021    11
# 2       27        112011.0      112011    11
# 3       27        112021.0      112021    11
# 4       13        112022.0      112022    11
# ..     ...             ...         ...   ...
# 659     53        537072.0      537072    53
# 660     53        537073.0      537073    53
# 661     53        537081.0      537081    53
# 662     53        537111.0      537111    53
# 663     53        537121.0      537121    53
#
#                                          Title  Job Zone  ... Dependability  \
# 0                             Chief Executives         5  ...         0.930
# 1              General and Operations Managers         4  ...         0.908
# 2          Advertising and Promotions Managers         4  ...         0.902
# 3                           Marketing Managers         4  ...         0.870
# 4                               Sales Managers         4  ...         0.914
# ..                                         ...       ...  ...           ...
# 659    Pump Operators, Except Wellhead Pumpers         2  ...         0.854
# 660                           Wellhead Pumpers         2  ...         0.874
# 661  Refuse and Recyclable Material Collectors         2  ...         0.928
# 662                 Mine Shuttle Car Operators         2  ...         0.728
# 663          Tank Car, Truck, and Ship Loaders         2  ...         0.886
#
#     Independence_y  Initiative  Innovation  Integrity  Leadership  \
# 0            0.908       0.950       0.854      0.960       0.994
# 1            0.798       0.870       0.730      0.860       0.918
# 2            0.808       0.912       0.798      0.834       0.806
# 3            0.776       0.906       0.830      0.834       0.874
# 4            0.860       0.956       0.826      0.928       0.914
# ..             ...         ...         ...        ...         ...
# 659          0.638       0.700       0.480      0.710       0.716
# 660          0.806       0.716       0.636      0.800       0.630
# 661          0.850       0.752       0.712      0.858       0.754
# 662          0.640       0.658       0.508      0.636       0.454
# 663          0.818       0.880       0.712      0.792       0.832
#
#      Persistence  Self Control  Social Orientation  Stress Tolerance
# 0          0.886         0.904               0.734             0.950
# 1          0.808         0.862               0.714             0.866
# 2          0.864         0.836               0.740             0.870
# 3          0.846         0.774               0.760             0.802
# 4          0.896         0.860               0.766             0.904
# ..           ...           ...                 ...               ...
# 659        0.526         0.798               0.644             0.902
# 660        0.684         0.718               0.564             0.658
# 661        0.796         0.890               0.572             0.868
# 662        0.660         0.682               0.600             0.674
# 663        0.808         0.790               0.530             0.746
#
# [664 rows x 34 columns]
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
